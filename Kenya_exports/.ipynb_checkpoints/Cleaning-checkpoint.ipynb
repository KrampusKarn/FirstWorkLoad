# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
East_af = pd.read_csv("EasternAFRI.csv")

# %%
East_af
# Out:
#    Country Name Country Code            Series Name 2012 [YR2012]  \
# 0       Comoros          COM       Trade (% of GDP)   40.81041894
# 1       Comoros          COM  GDP growth (annual %)   3.168409869
# 2         Kenya          KEN       Trade (% of GDP)   51.62369202
# 3         Kenya          KEN  GDP growth (annual %)   4.568679614
# 4   South Sudan          SSD       Trade (% of GDP)   71.61981139
# 5   South Sudan          SSD  GDP growth (annual %)  -46.08212237
# 6         Sudan          SDN       Trade (% of GDP)   21.85617452
# 7         Sudan          SDN  GDP growth (annual %)   -17.0046884
# 8       Somalia          SOM       Trade (% of GDP)            ..
# 9       Somalia          SOM  GDP growth (annual %)            ..
# 10     Tanzania          TZA       Trade (% of GDP)   54.36894908
# 11     Tanzania          TZA  GDP growth (annual %)    4.50015356
# 12       Uganda          UGA       Trade (% of GDP)   43.50213714
# ...
