# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os
import warnings
warnings.filterwarnings("ignore")

plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
Kenya_ex = pd.read_csv("Kenya2012_2022exportsHS2-6.csv")
Kenya_im = pd.read_csv("Kenya2012_2022importHS2-6.csv")
Africa_east = pd.read_csv("EastAfricadata.csv")

# %% [markdown]
# ## First Data Inspection
# This will cover methods use to inspect what kind of data types and the overall attributes of the dataframe.
# Exports followed by Imports

# %%
Kenya_ex
# Out:
#                   HS2  HS2 ID                HS4  HS4 ID  \
# 0        Live animals     101             Horses   10101
# 1        Live animals     101             Horses   10101
# 2        Live animals     101             Horses   10101
# 3        Live animals     101             Bovine   10102
# 4        Live animals     101             Bovine   10102
# ...               ...     ...                ...     ...
# 40159  Art & antiques    2197             Prints  219702
# 40160  Art & antiques    2197         Sculptures  219703
# 40161  Art & antiques    2197     Revenue Stamps  219704
# 40162  Art & antiques    2197  Collector's Items  219705
# 40163  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6 ID  \
# 0                              Pure-bred Breeding Horses   1010111
# 1                                    Non-breeding Horses   1010119
# 2                   Live Donkeys, Mules, and Crossbreeds   1010120
# 3                              Pure-bred Breeding Cattle   1010210
# 4                                    Non-breeding Cattle   1010290
# ...                                                  ...       ...
# 40159        Original engravings, prints and lithographs  21970200
# 40160  Original sculptures and statuary, in any material  21970300
# 40161  Used postage and revenue stamps, first day cov...  21970400
# 40162                  Collections and collectors pieces  21970500
# 40163              Antiques older than one hundred years  21970600
#
#                  Section  Section ID  Trade Value  Year
# 0        Animal Products           1       3846.0  2012
# 1        Animal Products           1      13300.0  2012
# 2        Animal Products           1       9355.0  2012
# 3        Animal Products           1      56766.0  2012
# 4        Animal Products           1    2624789.0  2012
# ...                  ...         ...          ...   ...
# 40159  Arts and Antiques          21       1849.0  2022
# 40160  Arts and Antiques          21     638981.0  2022
# 40161  Arts and Antiques          21       2507.0  2022
# 40162  Arts and Antiques          21     391474.0  2022
# 40163  Arts and Antiques          21      58115.0  2022
#
# [40164 rows x 10 columns]

# %%
Kenya_ex.info()
#The HS stands for Harmonised system code used for exporters and importers to pin point the exact categories, types and anyother specific products
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40164 entries, 0 to 40163
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HS2          40164 non-null  object
#  1   HS2 ID       40164 non-null  int64
#  2   HS4          40164 non-null  object
#  3   HS4 ID       40164 non-null  int64
#  4   HS6          40164 non-null  object
#  5   HS6 ID       40164 non-null  int64
#  6   Section      40164 non-null  object
#  7   Section ID   40164 non-null  int64
#  8   Trade Value  40164 non-null  float64
#  9   Year         40164 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 3.1+ MB

# %%
Kenya_ex.mean(numeric_only=True)
# Out:
# HS2 ID         1.133208e+03
# HS4 ID         1.133348e+05
# HS6 ID         1.133352e+07
# Section ID     1.077791e+01
# Trade Value    1.766068e+06
# Year           2.016976e+03
# dtype: float64

# %%
Kenya_ex.nunique(axis=0)
# Out:
# HS2               96
# HS2 ID            96
# HS4             1212
# HS4 ID          1212
# HS6             4514
# HS6 ID          4522
# Section           21
# Section ID        21
# Trade Value    31600
# Year              11
# dtype: int64

# %%
Kenya_ex.describe()
# Out:
#              HS2 ID         HS4 ID        HS6 ID    Section ID   Trade Value  \
# count  40164.000000   40164.000000  4.016400e+04  40164.000000  4.016400e+04
# mean    1133.208147  113334.836495  1.133352e+07     10.777911  1.766068e+06
# std      562.378719   56242.164773  5.624220e+06      5.349659  2.452216e+07
# min      101.000000   10101.000000  1.010111e+06      1.000000  1.000000e+00
# 25%      629.000000   62933.000000  6.293390e+06      6.000000  3.592750e+03
# 50%     1161.000000  116104.000000  1.161045e+07     11.000000  2.906650e+04
# 75%     1684.000000  168420.000000  1.684210e+07     16.000000  1.989582e+05
# max     2197.000000  219706.000000  2.197060e+07     21.000000  1.390005e+09
#
#                Year
# count  40164.000000
# mean    2016.975700
# std        3.144862
# min     2012.000000
# 25%     2014.000000
# 50%     2017.000000
# 75%     2020.000000
# max     2022.000000

# %%
Kenya_ex.isnull().sum()
# Out:
# HS2            0
# HS2 ID         0
# HS4            0
# HS4 ID         0
# HS6            0
# HS6 ID         0
# Section        0
# Section ID     0
# Trade Value    0
# Year           0
# dtype: int64

# %%
Kenya_ex['Product each industry'] = Kenya_ex.groupby('Section')['HS6'].transform('count')

# %%
Kenya_ex
# Out:
#                   HS2  HS2 ID                HS4  HS4 ID  \
# 0        Live animals     101             Horses   10101
# 1        Live animals     101             Horses   10101
# 2        Live animals     101             Horses   10101
# 3        Live animals     101             Bovine   10102
# 4        Live animals     101             Bovine   10102
# ...               ...     ...                ...     ...
# 40159  Art & antiques    2197             Prints  219702
# 40160  Art & antiques    2197         Sculptures  219703
# 40161  Art & antiques    2197     Revenue Stamps  219704
# 40162  Art & antiques    2197  Collector's Items  219705
# 40163  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6 ID  \
# 0                              Pure-bred Breeding Horses   1010111
# 1                                    Non-breeding Horses   1010119
# 2                   Live Donkeys, Mules, and Crossbreeds   1010120
# 3                              Pure-bred Breeding Cattle   1010210
# 4                                    Non-breeding Cattle   1010290
# ...                                                  ...       ...
# 40159        Original engravings, prints and lithographs  21970200
# 40160  Original sculptures and statuary, in any material  21970300
# 40161  Used postage and revenue stamps, first day cov...  21970400
# 40162                  Collections and collectors pieces  21970500
# 40163              Antiques older than one hundred years  21970600
#
#                  Section  Section ID  Trade Value  Year  Product each industry
# 0        Animal Products           1       3846.0  2012                   1425
# 1        Animal Products           1      13300.0  2012                   1425
# 2        Animal Products           1       9355.0  2012                   1425
# 3        Animal Products           1      56766.0  2012                   1425
# 4        Animal Products           1    2624789.0  2012                   1425
# ...                  ...         ...          ...   ...                    ...
# 40159  Arts and Antiques          21       1849.0  2022                     77
# 40160  Arts and Antiques          21     638981.0  2022                     77
# 40161  Arts and Antiques          21       2507.0  2022                     77
# 40162  Arts and Antiques          21     391474.0  2022                     77
# 40163  Arts and Antiques          21      58115.0  2022                     77
#
# [40164 rows x 11 columns]

# %% [markdown]
# ## This part is the Imports

# %%
Kenya_im
# Out:
#                   HS2  HS2 ID                HS4  HS4 ID  \
# 0        Live animals     101             Horses   10101
# 1        Live animals     101             Horses   10101
# 2        Live animals     101             Horses   10101
# 3        Live animals     101             Bovine   10102
# 4        Live animals     101    Sheep and Goats   10104
# ...               ...     ...                ...     ...
# 46363  Art & antiques    2197             Prints  219702
# 46364  Art & antiques    2197         Sculptures  219703
# 46365  Art & antiques    2197     Revenue Stamps  219704
# 46366  Art & antiques    2197  Collector's Items  219705
# 46367  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6 ID  \
# 0                              Pure-bred Breeding Horses   1010111
# 1                                    Non-breeding Horses   1010119
# 2                   Live Donkeys, Mules, and Crossbreeds   1010120
# 3                                    Non-breeding Cattle   1010290
# 4                                             Live Sheep   1010410
# ...                                                  ...       ...
# 46363        Original engravings, prints and lithographs  21970200
# 46364  Original sculptures and statuary, in any material  21970300
# 46365  Used postage and revenue stamps, first day cov...  21970400
# 46366                  Collections and collectors pieces  21970500
# 46367              Antiques older than one hundred years  21970600
#
#                  Section  Section ID  Trade Value  Year  Product each industry
# 0        Animal Products           1    185562.00  2012                   1360
# 1        Animal Products           1     16239.00  2012                   1360
# 2        Animal Products           1      8204.00  2012                   1360
# 3        Animal Products           1     12187.00  2012                   1360
# 4        Animal Products           1         5.00  2012                   1360
# ...                  ...         ...          ...   ...                    ...
# 46363  Arts and Antiques          21     12479.00  2022                     74
# 46364  Arts and Antiques          21     68007.00  2022                     74
# 46365  Arts and Antiques          21      4810.00  2022                     74
# 46366  Arts and Antiques          21     82799.00  2022                     74
# 46367  Arts and Antiques          21      2067.00  2022                     74
#
# [46368 rows x 11 columns]

# %%
Kenya_im['Product each industry'] = Kenya_im.groupby('Section')['HS6'].transform('count')

# %%
#Next we do the imports for Kenya
Kenya_im_2012 = Kenya_im[Kenya_im.Year == 2012 ].copy()
Kenya_im_2012
# Out:
#                  HS2  HS2 ID                HS4  HS4 ID  \
# 0       Live animals     101             Horses   10101
# 1       Live animals     101             Horses   10101
# 2       Live animals     101             Horses   10101
# 3       Live animals     101             Bovine   10102
# 4       Live animals     101    Sheep and Goats   10104
# ...              ...     ...                ...     ...
# 4108  Art & antiques    2197          Paintings  219701
# 4109  Art & antiques    2197             Prints  219702
# 4110  Art & antiques    2197         Sculptures  219703
# 4111  Art & antiques    2197     Revenue Stamps  219704
# 4112  Art & antiques    2197  Collector's Items  219705
#
#                                                     HS6    HS6 ID  \
# 0                             Pure-bred Breeding Horses   1010111
# 1                                   Non-breeding Horses   1010119
# 2                  Live Donkeys, Mules, and Crossbreeds   1010120
# 3                                   Non-breeding Cattle   1010290
# 4                                            Live Sheep   1010410
# ...                                                 ...       ...
# 4108               Collages, similar decorative plaques  21970190
# 4109        Original engravings, prints and lithographs  21970200
# 4110  Original sculptures and statuary, in any material  21970300
# 4111  Used postage and revenue stamps, first day cov...  21970400
# 4112                  Collections and collectors pieces  21970500
#
#                 Section  Section ID  Trade Value  Year
# 0       Animal Products           1    185562.00  2012
# 1       Animal Products           1     16239.00  2012
# 2       Animal Products           1      8204.00  2012
# 3       Animal Products           1     12187.00  2012
# 4       Animal Products           1         5.00  2012
# ...                 ...         ...          ...   ...
# 4108  Arts and Antiques          21    280945.00  2012
# 4109  Arts and Antiques          21     22842.00  2012
# 4110  Arts and Antiques          21  10716100.00  2012
# 4111  Arts and Antiques          21       270.00  2012
# 4112  Arts and Antiques          21     24793.00  2012
#
# [4113 rows x 10 columns]

# %%
Kenya_im_2022 = Kenya_im[Kenya_im.Year == 2022 ].copy()
Kenya_im_2022
# Out:
#                   HS2  HS2 ID                HS4  HS4 ID  \
# 42132    Live animals     101             Horses   10101
# 42133    Live animals     101             Horses   10101
# 42134    Live animals     101             Bovine   10102
# 42135    Live animals     101             Bovine   10102
# 42136    Live animals     101               Pigs   10103
# ...               ...     ...                ...     ...
# 46363  Art & antiques    2197             Prints  219702
# 46364  Art & antiques    2197         Sculptures  219703
# 46365  Art & antiques    2197     Revenue Stamps  219704
# 46366  Art & antiques    2197  Collector's Items  219705
# 46367  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6 ID  \
# 42132                          Pure-bred Breeding Horses   1010111
# 42133                                Non-breeding Horses   1010119
# 42134                          Pure-bred Breeding Cattle   1010210
# 42135                                Non-breeding Cattle   1010290
# 42136  Pigs Weighing Over 50 kg (Excluding Breeding P...   1010392
# ...                                                  ...       ...
# 46363        Original engravings, prints and lithographs  21970200
# 46364  Original sculptures and statuary, in any material  21970300
# 46365  Used postage and revenue stamps, first day cov...  21970400
# 46366                  Collections and collectors pieces  21970500
# 46367              Antiques older than one hundred years  21970600
#
#                  Section  Section ID  Trade Value  Year
# 42132    Animal Products           1    402123.00  2022
# 42133    Animal Products           1     13145.00  2022
# 42134    Animal Products           1   2098061.00  2022
# 42135    Animal Products           1   2873054.00  2022
# 42136    Animal Products           1      2726.00  2022
# ...                  ...         ...          ...   ...
# 46363  Arts and Antiques          21     12479.00  2022
# 46364  Arts and Antiques          21     68007.00  2022
# 46365  Arts and Antiques          21      4810.00  2022
# 46366  Arts and Antiques          21     82799.00  2022
# 46367  Arts and Antiques          21      2067.00  2022
#
# [4236 rows x 10 columns]

# %%
Kenya_ex_2012 = Kenya_ex[Kenya_ex['Year'] == 2012].copy()
Kenya_ex_2012
# Out:
#                  HS2  HS2 ID                HS4  HS4 ID  \
# 0       Live animals     101             Horses   10101
# 1       Live animals     101             Horses   10101
# 2       Live animals     101             Horses   10101
# 3       Live animals     101             Bovine   10102
# 4       Live animals     101             Bovine   10102
# ...              ...     ...                ...     ...
# 3545  Art & antiques    2197             Prints  219702
# 3546  Art & antiques    2197         Sculptures  219703
# 3547  Art & antiques    2197     Revenue Stamps  219704
# 3548  Art & antiques    2197  Collector's Items  219705
# 3549  Art & antiques    2197           Antiques  219706
#
#                                                     HS6    HS6 ID  \
# 0                             Pure-bred Breeding Horses   1010111
# 1                                   Non-breeding Horses   1010119
# 2                  Live Donkeys, Mules, and Crossbreeds   1010120
# 3                             Pure-bred Breeding Cattle   1010210
# 4                                   Non-breeding Cattle   1010290
# ...                                                 ...       ...
# 3545        Original engravings, prints and lithographs  21970200
# 3546  Original sculptures and statuary, in any material  21970300
# 3547  Used postage and revenue stamps, first day cov...  21970400
# 3548                  Collections and collectors pieces  21970500
# 3549              Antiques older than one hundred years  21970600
#
#                 Section  Section ID  Trade Value  Year  Product each industry
# 0       Animal Products           1       3846.0  2012                   1425
# 1       Animal Products           1      13300.0  2012                   1425
# 2       Animal Products           1       9355.0  2012                   1425
# 3       Animal Products           1      56766.0  2012                   1425
# 4       Animal Products           1    2624789.0  2012                   1425
# ...                 ...         ...          ...   ...                    ...
# 3545  Arts and Antiques          21     208799.0  2012                     77
# 3546  Arts and Antiques          21     772108.0  2012                     77
# 3547  Arts and Antiques          21       2975.0  2012                     77
# 3548  Arts and Antiques          21      38048.0  2012                     77
# 3549  Arts and Antiques          21      50465.0  2012                     77
#
# [3550 rows x 11 columns]

# %%
Kenya_ex_2012.nlargest(10, 'Trade Value')
# Out:
#                                                     HS2  HS2 ID  \
# 217                          Coffee, tea, mate & spices     209
# 119   Live trees, plants, bulbs, cut flowers, & orna...     206
# 209                          Coffee, tea, mate & spices     209
# 578   Mineral fuels, mineral oils and products of th...     527
# 2130                  Precious stones, metals, & pearls    1471
# 140                  Edible vegetables, roots, & tubers     207
# 493                               Tobacco & substitutes     424
# 3249                Ships, boats, & floating structures    1789
# 694                                 Inorganic chemicals     628
# 907                             Pharmaceutical products     630
#
#                             HS4  HS4 ID  \
# 217                         Tea   20902
# 119                 Cut Flowers   20603
# 209                      Coffee   20901
# 578           Refined Petroleum   52710
# 2130                       Gold  147108
# 140                     Legumes   20708
# 493              Rolled Tobacco   42402
# 3249  Passenger and Cargo Ships  178901
# 694                  Carbonates   62836
# 907        Packaged Medicaments   63004
#
#                                                     HS6    HS6 ID  \
# 217         Black Tea (Fermented/Partly, >3kg packages)   2090240
# 119      Fresh cut flowers and flower buds for bouquets   2060310
# 209                Unroasted Coffee (Non-Decaffeinated)   2090111
# 578   Oils petroleum, bituminous, distillates, excep...   5271000
# 2130               Gold in unwrought forms non-monetary  14710812
# 140          Beans Shelled or Unshelled (Fresh/Chilled)   2070820
# 493                       Cigarettes containing tobacco   4240220
# 3249    Cargo vessels other than tanker or refrigerated  17890190
# 694                                  Disodium carbonate   6283620
# 907                          Medicaments nes, in dosage   6300490
#
#                  Section  Section ID   Trade Value  Year  \
# 217   Vegetable Products           2  1.016246e+09  2012
# 119   Vegetable Products           2  6.001379e+08  2012
# 209   Vegetable Products           2  2.639597e+08  2012
# 578     Mineral Products           5  2.302444e+08  2012
# 2130     Precious Metals          14  1.889879e+08  2012
# 140   Vegetable Products           2  1.474748e+08  2012
# 493           Foodstuffs           4  8.450817e+07  2012
# 3249      Transportation          17  8.319842e+07  2012
# 694    Chemical Products           6  8.119905e+07  2012
# 907    Chemical Products           6  6.884685e+07  2012
#
#       Product each industry
# 217                    2338
# 119                    2338
# 209                    2338
# 578                    1076
# 2130                    303
# 140                    2338
# 493                    1679
# 3249                   1042
# 694                    5659
# 907                    5659

# %% [markdown]
# ### Concatanating both CSVs to make comparison

# %%
Kenya_concat = pd.concat([Kenya_ex, Kenya_im], axis=0, keys=["Kenya_ex", "Kenya_im"], names=["Edition"]).reset_index()

# %%
Kenya_concat.rename(columns = {'HS6 ID': 'HS6_ID', 'HS4 ID': 'HS4_ID', 'HS2 ID': 'HS2_ID', 
                              'Section ID': 'Section_ID', 'Trade Value': 'Trade_Value', 'Product each industry': 'Product_per_industry'})
# Out:
#         Edition  level_1             HS2  HS2_ID                HS4  HS4_ID  \
# 0      Kenya_ex        0    Live animals     101             Horses   10101
# 1      Kenya_ex        1    Live animals     101             Horses   10101
# 2      Kenya_ex        2    Live animals     101             Horses   10101
# 3      Kenya_ex        3    Live animals     101             Bovine   10102
# 4      Kenya_ex        4    Live animals     101             Bovine   10102
# ...         ...      ...             ...     ...                ...     ...
# 86527  Kenya_im    46363  Art & antiques    2197             Prints  219702
# 86528  Kenya_im    46364  Art & antiques    2197         Sculptures  219703
# 86529  Kenya_im    46365  Art & antiques    2197     Revenue Stamps  219704
# 86530  Kenya_im    46366  Art & antiques    2197  Collector's Items  219705
# 86531  Kenya_im    46367  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6_ID  \
# 0                              Pure-bred Breeding Horses   1010111
# 1                                    Non-breeding Horses   1010119
# 2                   Live Donkeys, Mules, and Crossbreeds   1010120
# 3                              Pure-bred Breeding Cattle   1010210
# 4                                    Non-breeding Cattle   1010290
# ...                                                  ...       ...
# 86527        Original engravings, prints and lithographs  21970200
# 86528  Original sculptures and statuary, in any material  21970300
# 86529  Used postage and revenue stamps, first day cov...  21970400
# 86530                  Collections and collectors pieces  21970500
# 86531              Antiques older than one hundred years  21970600
#
#                  Section  Section_ID  Trade_Value  Year  Product_per_industry
# 0        Animal Products           1      3846.00  2012                  1425
# 1        Animal Products           1     13300.00  2012                  1425
# 2        Animal Products           1      9355.00  2012                  1425
# 3        Animal Products           1     56766.00  2012                  1425
# 4        Animal Products           1   2624789.00  2012                  1425
# ...                  ...         ...          ...   ...                   ...
# 86527  Arts and Antiques          21     12479.00  2022                    74
# 86528  Arts and Antiques          21     68007.00  2022                    74
# 86529  Arts and Antiques          21      4810.00  2022                    74
# 86530  Arts and Antiques          21     82799.00  2022                    74
# 86531  Arts and Antiques          21      2067.00  2022                    74
#
# [86532 rows x 13 columns]

# %% [markdown]
# ### Since 2012, the dataframe of Kenya's export trade value displayed, we see a pattern that most traded product is Vegetable Products

# %%
Kenya_ex_2022 = Kenya_ex[Kenya_ex['Year'] == 2022].copy()
Kenya_ex_2022
# Out:
#                   HS2  HS2 ID                HS4  HS4 ID  \
# 36638    Live animals     101             Horses   10101
# 36639    Live animals     101             Horses   10101
# 36640    Live animals     101             Bovine   10102
# 36641    Live animals     101             Bovine   10102
# 36642    Live animals     101               Pigs   10103
# ...               ...     ...                ...     ...
# 40159  Art & antiques    2197             Prints  219702
# 40160  Art & antiques    2197         Sculptures  219703
# 40161  Art & antiques    2197     Revenue Stamps  219704
# 40162  Art & antiques    2197  Collector's Items  219705
# 40163  Art & antiques    2197           Antiques  219706
#
#                                                      HS6    HS6 ID  \
# 36638                          Pure-bred Breeding Horses   1010111
# 36639                                Non-breeding Horses   1010119
# 36640                          Pure-bred Breeding Cattle   1010210
# 36641                                Non-breeding Cattle   1010290
# 36642                            Pure-bred Breeding Pigs   1010310
# ...                                                  ...       ...
# 40159        Original engravings, prints and lithographs  21970200
# 40160  Original sculptures and statuary, in any material  21970300
# 40161  Used postage and revenue stamps, first day cov...  21970400
# 40162                  Collections and collectors pieces  21970500
# 40163              Antiques older than one hundred years  21970600
#
#                  Section  Section ID  Trade Value  Year  Product each industry
# 36638    Animal Products           1       7556.0  2022                   1425
# 36639    Animal Products           1       3643.0  2022                   1425
# 36640    Animal Products           1     243891.0  2022                   1425
# 36641    Animal Products           1     443989.0  2022                   1425
# 36642    Animal Products           1      74587.0  2022                   1425
# ...                  ...         ...          ...   ...                    ...
# 40159  Arts and Antiques          21       1849.0  2022                     77
# 40160  Arts and Antiques          21     638981.0  2022                     77
# 40161  Arts and Antiques          21       2507.0  2022                     77
# 40162  Arts and Antiques          21     391474.0  2022                     77
# 40163  Arts and Antiques          21      58115.0  2022                     77
#
# [3526 rows x 11 columns]

# %%
Kenya_ex_2022.nlargest(10,'Trade Value')
# Out:
#                                                      HS2  HS2 ID  \
# 36873                         Coffee, tea, mate & spices     209
# 36762  Live trees, plants, bulbs, cut flowers, & orna...     206
# 36864                         Coffee, tea, mate & spices     209
# 37222                                 Ores, slag and ash     526
# 36833                  Edible fruits, nuts & fruit peels     208
# 38773                  Precious stones, metals, & pearls    1471
# 36987            Animal or vegetable fats, oils, & waxes     315
# 36828                  Edible fruits, nuts & fruit peels     208
# 37350                                Inorganic chemicals     628
# 37163                              Tobacco & substitutes     424
#
#                    HS4  HS4 ID  \
# 36873              Tea   20902
# 36762      Cut Flowers   20603
# 36864           Coffee   20901
# 37222     Titanium Ore   52614
# 36833  Tropical Fruits   20804
# 38773             Gold  147108
# 36987         Palm Oil   31511
# 36828       Other Nuts   20802
# 37350       Carbonates   62836
# 37163   Rolled Tobacco   42402
#
#                                                   HS6    HS6 ID  \
# 36873     Black Tea (Fermented/Partly, >3kg packages)   2090240
# 36762  Fresh cut flowers and flower buds for bouquets   2060310
# 36864            Unroasted Coffee (Non-Decaffeinated)   2090111
# 37222                  Titanium ores and concentrates   5261400
# 36833                          Avocados (Fresh/Dried)   2080440
# 38773            Gold in unwrought forms non-monetary  14710812
# 36987            Palm oil or fractions simply refined   3151190
# 36828                   Other Fresh/Dried Edible Nuts   2080290
# 37350                              Disodium carbonate   6283620
# 37163                   Cigarettes containing tobacco   4240220
#
#                                 Section  Section ID   Trade Value  Year  \
# 36873                Vegetable Products           2  1.349478e+09  2022
# 36762                Vegetable Products           2  6.577071e+08  2022
# 36864                Vegetable Products           2  3.284433e+08  2022
# 37222                  Mineral Products           5  2.898481e+08  2022
# 36833                Vegetable Products           2  1.824063e+08  2022
# 38773                   Precious Metals          14  1.598451e+08  2022
# 36987  Animal and Vegetable Bi-Products           3  1.463654e+08  2022
# 36828                Vegetable Products           2  1.056770e+08  2022
# 37350                 Chemical Products           6  9.880694e+07  2022
# 37163                        Foodstuffs           4  9.717860e+07  2022
#
#        Product each industry
# 36873                   2338
# 36762                   2338
# 36864                   2338
# 37222                   1076
# 36833                   2338
# 38773                    303
# 36987                    463
# 36828                   2338
# 37350                   5659
# 37163                   1679

# %%
def most_traded(year, section, n):
    return Kenya_ex[(Kenya_ex.Year == year) &  (Kenya_ex.Section == section)].nlargest(n, 'Trade Value')

# %%
most_traded(2018, 'Animal Products', 5)
# Out:
#                                             HS2  HS2 ID  \
# 22154                       Meat & edible offal     102
# 22191             Fish, crustaceans, & molluscs     103
# 22194             Fish, crustaceans, & molluscs     103
# 22228  Edible products of animal origin, n.e.s.     104
# 22155                       Meat & edible offal     102
#
#                           HS4  HS4 ID  \
# 22154     Sheep and Goat Meat   10204
# 22191  Non-fillet Frozen Fish   10303
# 22194            Fish Fillets   10304
# 22228       Concentrated Milk   10402
# 22155              Horse Meat   10205
#
#                                                      HS6   HS6 ID  \
# 22154                                          Goat Meat  1020450
# 22191                    Fish (Other Varieties) (Frozen)  1030379
# 22194                              Fish Fillets (Frozen)  1030420
# 22228               Unsweetened Cream Powder (<1.5% Fat)  1040221
# 22155  Meat from Horses/Donkeys/Mules/Hinnies (Fresh,...  1020500
#
#                Section  Section ID  Trade Value  Year  Product each industry
# 22154  Animal Products           1   33147783.0  2018                   1425
# 22191  Animal Products           1   23728098.0  2018                   1425
# 22194  Animal Products           1   12200615.0  2018                   1425
# 22228  Animal Products           1   11878264.0  2018                   1425
# 22155  Animal Products           1    8898610.0  2018                   1425

# %%
most_traded(2022,'Animal Products', 5)
# Out:
#                                  HS2  HS2 ID  \
# 36666            Meat & edible offal     102
# 36658            Meat & edible offal     102
# 36659            Meat & edible offal     102
# 36704  Fish, crustaceans, & molluscs     103
# 36648                   Live animals     101
#
#                                            HS4  HS4 ID  \
# 36666                      Sheep and Goat Meat   10204
# 36658                      Sheep and Goat Meat   10204
# 36659                      Sheep and Goat Meat   10204
# 36704  Fish: dried, salted, smoked or in brine   10305
# 36648                            Other Animals   10106
#
#                                         HS6   HS6 ID          Section  \
# 36666                             Goat Meat  1020450  Animal Products
# 36658   Fresh/Chilled Lamb (Whole & Halves)  1020410  Animal Products
# 36659  Fresh/Chilled Sheep (Whole & Halves)  1020421  Animal Products
# 36704                Dried Cod (Not Smoked)  1030551  Animal Products
# 36648         Live Animals (Not Farm Types)  1010600  Animal Products
#
#        Section ID  Trade Value  Year  Product each industry
# 36666           1   50461216.0  2022                   1425
# 36658           1   17887312.0  2022                   1425
# 36659           1   15570623.0  2022                   1425
# 36704           1   12346551.0  2022                   1425
# 36648           1    9120787.0  2022                   1425

# %% [markdown]
# ### What we got from data Inspection

# %%
Kenya_section = Kenya_ex[Kenya_ex.Section == 'Animal Products'].copy()
Kenya_section
#looking at one certain section to find counts
# Out:
#                                       HS2  HS2 ID  \
# 0                            Live animals     101
# 1                            Live animals     101
# 2                            Live animals     101
# 3                            Live animals     101
# 4                            Live animals     101
# ...                                   ...     ...
# 36750  Animal originated products, n.e.s.     105
# 36751  Animal originated products, n.e.s.     105
# 36752  Animal originated products, n.e.s.     105
# 36753  Animal originated products, n.e.s.     105
# 36754  Animal originated products, n.e.s.     105
#
#                                   HS4  HS4 ID  \
# 0                              Horses   10101
# 1                              Horses   10101
# 2                              Horses   10101
# 3                              Bovine   10102
# 4                              Bovine   10102
# ...                               ...     ...
# 36750                Coral and Shells   10508
# 36751  Pharmaceutical Animal Products   10510
# 36752  Other Inedible Animal Products   10511
# 36753  Other Inedible Animal Products   10511
# 36754  Other Inedible Animal Products   10511
#
#                                         HS6   HS6 ID          Section  \
# 0                 Pure-bred Breeding Horses  1010111  Animal Products
# 1                       Non-breeding Horses  1010119  Animal Products
# 2      Live Donkeys, Mules, and Crossbreeds  1010120  Animal Products
# 3                 Pure-bred Breeding Cattle  1010210  Animal Products
# 4                       Non-breeding Cattle  1010290  Animal Products
# ...                                     ...      ...              ...
# 36750                      Coral and Shells  1050800  Animal Products
# 36751        Pharmaceutical Animal Products  1051000  Animal Products
# 36752                          Bovine Semen  1051110  Animal Products
# 36753         Inedible Fish and Crustaceans  1051191  Animal Products
# 36754             Domestic Animal Carcasses  1051199  Animal Products
#
#        Section ID  Trade Value  Year  Product each industry
# 0               1       3846.0  2012                   1425
# 1               1      13300.0  2012                   1425
# 2               1       9355.0  2012                   1425
# 3               1      56766.0  2012                   1425
# 4               1    2624789.0  2012                   1425
# ...           ...          ...   ...                    ...
# 36750           1     176158.0  2022                   1425
# 36751           1     269290.0  2022                   1425
# 36752           1     245477.0  2022                   1425
# 36753           1      60427.0  2022                   1425
# 36754           1     316704.0  2022                   1425
#
# [1425 rows x 11 columns]

# %% [markdown]
# ## Export Aggregation

# %%
agg = Kenya_ex.groupby(["HS2", "Section"]).agg(
    TotalTrade=('Trade Value', 'sum'),  # Rename to TotalTrade for clarity
    UniqueProduct=('HS6', 'count'),
)

# Step 2: Find the year with the highest trade value within each group
idx = Kenya_ex.groupby(["HS2", "Section"])['Trade Value'].idxmax()

# Step 3: Extract the year with the highest trade value
agg['YearWithMaxTrade'] = Kenya_ex.loc[idx, 'Year'].values

# %%
Kenya_ex.columns
# Out:
# Index(['HS2', 'HS2 ID', 'HS4', 'HS4 ID', 'HS6', 'HS6 ID', 'Section',
#        'Section ID', 'Trade Value', 'Year', 'Product each industry'],
#       dtype='object')

# %%
agg
# Out:
#                                                                             TotalTrade  \
# HS2                                     Section
# Aircraft and spacecraft                 Transportation                    1.459294e+08
# Aluminum articles                       Metals                            3.368558e+08
# Animal or vegetable fats, oils, & waxes Animal and Vegetable Bi-Products  1.526059e+09
# Animal originated products, n.e.s.      Animal Products                   2.915963e+07
# Art & antiques                          Arts and Antiques                 1.701884e+07
# ...                                                                                ...
# Weapons                                 Weapons                           6.026495e+06
# Wood pulp & paper scrap                 Paper Goods                       1.726830e+07
# Wood, wood articles, & charcoal         Wood Products                     1.694825e+08
# Wool & animal hair                      Textiles                          5.136518e+07
# Zinc articles                           Metals                            3.470806e+07
#
#                                                                           UniqueProduct  \
# HS2                                     Section
# Aircraft and spacecraft                 Transportation                              121
# Aluminum articles                       Metals                                      337
# Animal or vegetable fats, oils, & waxes Animal and Vegetable Bi-Products            463
# Animal originated products, n.e.s.      Animal Products                             116
# Art & antiques                          Arts and Antiques                            77
# ...                                                                                 ...
# Weapons                                 Weapons                                      77
# Wood pulp & paper scrap                 Paper Goods                                  80
# Wood, wood articles, & charcoal         Wood Products                               471
# Wool & animal hair                      Textiles                                    161
# Zinc articles                           Metals                                       86
#
#                                                                           YearWithMaxTrade
# HS2                                     Section
# Aircraft and spacecraft                 Transportation                                2014
# Aluminum articles                       Metals                                        2013
# Animal or vegetable fats, oils, & waxes Animal and Vegetable Bi-Products              2022
# Animal originated products, n.e.s.      Animal Products                               2015
# Art & antiques                          Arts and Antiques                             2018
# ...                                                                                    ...
# Weapons                                 Weapons                                       2012
# Wood pulp & paper scrap                 Paper Goods                                   2012
# Wood, wood articles, & charcoal         Wood Products                                 2013
# Wool & animal hair                      Textiles                                      2018
# Zinc articles                           Metals                                        2022
#
# [96 rows x 3 columns]

# %%
#before making correlation we will first look at the total trade value
Kenya_extotaltrade = Kenya_ex.groupby(['Year'])['Trade Value'].sum()
pd.options.display.float_format = '{:.2f}'.format
Kenya_extotaltrade.reset_index()
# Out:
#     Year   Trade Value
# 0   2012 5381065449.00
# 1   2013 6252921123.00
# 2   2014 6255924691.00
# 3   2015 6300150565.00
# 4   2016 6061765727.00
# 5   2017 6125540454.00
# 6   2018 6681927464.00
# 7   2019 6556288362.00
# 8   2020 6704909582.00
# 9   2021 7270116152.00
# 10  2022 7341762868.00

# %%
sns.barplot(x=Kenya_extotaltrade.index, y=Kenya_extotaltrade.values)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Total Trade Value')
plt.title('Total Trade Value per Year')
#compared with the most exported goods which is vegetable products we can see a correlating trend between Total Trade value
# Out:
# Text(0.5, 1.0, 'Total Trade Value per Year')

# %%
color_pal = sns.color_palette()
Kenya_extotaltrade.plot (style = '-',
                  figsize = (10,5),
                  ms = 1,
                  color = color_pal[0],
                  title = 'Kenya total trade')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Group by year and section to find the total trade value per section per year
# This will show the Year and Section as the multi-level indices
yearly_exports = Kenya_ex.groupby(['Year', 'Section'])['Trade Value'].sum().reset_index()

# Pivot the data to get a better format for plotting
pivot_exports = yearly_exports.pivot(index='Year', columns='Section', values='Trade Value').fillna(0)

# %%
yearly_exports
# Out:
#      Year                           Section   Trade Value
# 0    2012                      Animal Hides  116632342.00
# 1    2012                   Animal Products  135418990.00
# 2    2012  Animal and Vegetable Bi-Products   66038164.00
# 3    2012                 Arts and Antiques    1659069.00
# 4    2012                 Chemical Products  345872493.00
# ..    ...                               ...           ...
# 226  2022                          Textiles  605827075.00
# 227  2022                    Transportation   53571783.00
# 228  2022                Vegetable Products 3145773148.00
# 229  2022                           Weapons       2127.00
# 230  2022                     Wood Products   18997103.00
#
# [231 rows x 3 columns]

# %%
pivot_exports.head()
# Out:
# Section  Animal Hides  Animal Products  Animal and Vegetable Bi-Products  \
# Year
# 2012     116632342.00     135418990.00                       66038164.00
# 2013     112220685.00     124667792.00                      125003582.00
# 2014     141457437.00     134873618.00                       75124494.00
# 2015      82645361.00     111601846.00                       82245616.00
# 2016      73830856.00     101775906.00                      112575979.00
#
# Section  Arts and Antiques  Chemical Products   Foodstuffs  \
# Year
# 2012            1659069.00       345872493.00 447239115.00
# 2013            1821453.00       480833483.00 570274584.00
# 2014            1882439.00       488328854.00 433851426.00
# 2015            1421631.00       461369577.00 582523916.00
# 2016            1127653.00       410869328.00 514798349.00
#
# Section  Footwear and Headwear  Instruments     Machines       Metals  ...  \
# Year                                                                   ...
# 2012               27663162.00  15527412.00 203615157.00 202661357.00  ...
# 2013               60976270.00  28835662.00 217383840.00 337329436.00  ...
# 2014               35779614.00  22739869.00 171520661.00 247101317.00  ...
# 2015               52767745.00  28056349.00 197298739.00 274297532.00  ...
# 2016               45436252.00  20373711.00 250040870.00 261355606.00  ...
#
# Section  Miscellaneous  Paper Goods  Plastics and Rubbers  Precious Metals  \
# Year
# 2012       33910953.00  76292025.00          136594973.00     196967554.00
# 2013       62826277.00 119802494.00          213538397.00     240704637.00
# 2014       50806518.00 123108274.00          128582572.00      43025848.00
# 2015       66249191.00 127542336.00          180083105.00      31325260.00
# 2016       62945479.00 124187584.00          154403192.00      23222474.00
#
# Section  Stone And Glass     Textiles  Transportation  Vegetable Products  \
# Year
# 2012         24945882.00 331517475.00    199439103.00       2412270993.00
# 2013         38346548.00 413784164.00    104121311.00       2417740145.00
# 2014         19064389.00 482539558.00     99389581.00       2578198504.00
# 2015         23116691.00 470830248.00    106387914.00       2577431750.00
# 2016         17062528.00 456785423.00    148584078.00       2616072962.00
#
# Section    Weapons  Wood Products
# Year
# 2012    1527574.00     9086484.00
# 2013    1971933.00    41175258.00
# 2014        777.00    34674383.00
# 2015     583460.00    11092510.00
# 2016     129833.00     8218357.00
#
# [5 rows x 21 columns]

# %%
# Create a correlation matrix using pandas

# Exclude non-numeric columns
corr_matrix = pivot_exports.select_dtypes(include=[ 'float64', 'int64'])

# Now compute the correlation matrix
corr_matrix= pivot_exports.corr()
corr_matrix
# Out:
# Section                           Animal Hides  Animal Products  \
# Section
# Animal Hides                              1.00            -0.29
# Animal Products                          -0.29             1.00
# Animal and Vegetable Bi-Products         -0.82             0.64
# Arts and Antiques                         0.63             0.38
# Chemical Products                        -0.51             0.59
# Foodstuffs                               -0.67             0.02
# Footwear and Headwear                    -0.60             0.09
# Instruments                              -0.46             0.16
# Machines                                 -0.10            -0.20
# Metals                                   -0.57             0.49
# Mineral Products                         -0.06            -0.03
# Miscellaneous                            -0.55             0.03
# Paper Goods                              -0.37             0.34
# Plastics and Rubbers                      0.18            -0.27
# Precious Metals                          -0.57             0.33
# Stone And Glass                          -0.43             0.74
# Textiles                                 -0.51             0.60
# Transportation                            0.38            -0.35
# Vegetable Products                       -0.59             0.58
# Weapons                                   0.19            -0.16
# Wood Products                             0.32             0.22
#
# Section                           Animal and Vegetable Bi-Products  \
# Section
# Animal Hides                                                 -0.82
# Animal Products                                               0.64
# Animal and Vegetable Bi-Products                              1.00
# Arts and Antiques                                            -0.28
# Chemical Products                                             0.78
# Foodstuffs                                                    0.58
# Footwear and Headwear                                         0.62
# Instruments                                                   0.46
# Machines                                                     -0.18
# Metals                                                        0.85
# Mineral Products                                              0.01
# Miscellaneous                                                 0.60
# Paper Goods                                                   0.53
# Plastics and Rubbers                                         -0.04
# Precious Metals                                               0.48
# Stone And Glass                                               0.76
# Textiles                                                      0.71
# Transportation                                               -0.59
# Vegetable Products                                            0.76
# Weapons                                                      -0.12
# Wood Products                                                 0.06
#
# Section                           Arts and Antiques  Chemical Products  \
# Section
# Animal Hides                                   0.63              -0.51
# Animal Products                                0.38               0.59
# Animal and Vegetable Bi-Products              -0.28               0.78
# Arts and Antiques                              1.00               0.06
# Chemical Products                              0.06               1.00
# Foodstuffs                                    -0.30               0.52
# Footwear and Headwear                         -0.29               0.68
# Instruments                                   -0.05               0.71
# Machines                                       0.01              -0.12
# Metals                                        -0.10               0.86
# Mineral Products                              -0.07               0.47
# Miscellaneous                                 -0.28               0.72
# Paper Goods                                    0.21               0.75
# Plastics and Rubbers                           0.08               0.14
# Precious Metals                               -0.39               0.18
# Stone And Glass                                0.15               0.65
# Textiles                                       0.08               0.86
# Transportation                                -0.00              -0.72
# Vegetable Products                             0.03               0.67
# Weapons                                        0.07              -0.15
# Wood Products                                  0.44               0.46
#
# Section                           Foodstuffs  Footwear and Headwear  \
# Section
# Animal Hides                           -0.67                  -0.60
# Animal Products                         0.02                   0.09
# Animal and Vegetable Bi-Products        0.58                   0.62
# Arts and Antiques                      -0.30                  -0.29
# Chemical Products                       0.52                   0.68
# Foodstuffs                              1.00                   0.86
# Footwear and Headwear                   0.86                   1.00
# Instruments                             0.56                   0.68
# Machines                                0.00                   0.10
# Metals                                  0.62                   0.82
# Mineral Products                        0.02                   0.16
# Miscellaneous                           0.77                   0.87
# Paper Goods                             0.55                   0.54
# Plastics and Rubbers                    0.41                   0.55
# Precious Metals                         0.33                   0.33
# Stone And Glass                         0.49                   0.61
# Textiles                                0.39                   0.48
# Transportation                         -0.57                  -0.57
# Vegetable Products                      0.41                   0.33
# Weapons                                 0.12                   0.15
# Wood Products                          -0.02                   0.30
#
# Section                           Instruments  Machines  Metals  ...  \
# Section                                                          ...
# Animal Hides                            -0.46     -0.10   -0.57  ...
# Animal Products                          0.16     -0.20    0.49  ...
# Animal and Vegetable Bi-Products         0.46     -0.18    0.85  ...
# Arts and Antiques                       -0.05      0.01   -0.10  ...
# Chemical Products                        0.71     -0.12    0.86  ...
# Foodstuffs                               0.56      0.00    0.62  ...
# Footwear and Headwear                    0.68      0.10    0.82  ...
# Instruments                              1.00      0.40    0.64  ...
# Machines                                 0.40      1.00   -0.11  ...
# Metals                                   0.64     -0.11    1.00  ...
# Mineral Products                         0.32     -0.07    0.09  ...
# Miscellaneous                            0.61     -0.01    0.79  ...
# Paper Goods                              0.46     -0.01    0.57  ...
# Plastics and Rubbers                     0.31      0.07    0.41  ...
# Precious Metals                          0.11     -0.03    0.23  ...
# Stone And Glass                          0.38     -0.14    0.82  ...
# Textiles                                 0.45     -0.10    0.69  ...
# Transportation                          -0.26      0.53   -0.59  ...
# Vegetable Products                       0.39     -0.18    0.61  ...
# Weapons                                  0.28      0.20    0.11  ...
# Wood Products                            0.33     -0.03    0.34  ...
#
# Section                           Miscellaneous  Paper Goods  \
# Section
# Animal Hides                              -0.55        -0.37
# Animal Products                            0.03         0.34
# Animal and Vegetable Bi-Products           0.60         0.53
# Arts and Antiques                         -0.28         0.21
# Chemical Products                          0.72         0.75
# Foodstuffs                                 0.77         0.55
# Footwear and Headwear                      0.87         0.54
# Instruments                                0.61         0.46
# Machines                                  -0.01        -0.01
# Metals                                     0.79         0.57
# Mineral Products                           0.38         0.48
# Miscellaneous                              1.00         0.75
# Paper Goods                                0.75         1.00
# Plastics and Rubbers                       0.43         0.03
# Precious Metals                           -0.06        -0.16
# Stone And Glass                            0.39         0.33
# Textiles                                   0.69         0.87
# Transportation                            -0.66        -0.75
# Vegetable Products                         0.54         0.73
# Weapons                                   -0.17        -0.49
# Wood Products                              0.10         0.16
#
# Section                           Plastics and Rubbers  Precious Metals  \
# Section
# Animal Hides                                      0.18            -0.57
# Animal Products                                  -0.27             0.33
# Animal and Vegetable Bi-Products                 -0.04             0.48
# Arts and Antiques                                 0.08            -0.39
# Chemical Products                                 0.14             0.18
# Foodstuffs                                        0.41             0.33
# Footwear and Headwear                             0.55             0.33
# Instruments                                       0.31             0.11
# Machines                                          0.07            -0.03
# Metals                                            0.41             0.23
# Mineral Products                                 -0.18            -0.24
# Miscellaneous                                     0.43            -0.06
# Paper Goods                                       0.03            -0.16
# Plastics and Rubbers                              1.00            -0.18
# Precious Metals                                  -0.18             1.00
# Stone And Glass                                   0.33             0.49
# Textiles                                         -0.11            -0.06
# Transportation                                    0.01            -0.19
# Vegetable Products                               -0.29            -0.00
# Weapons                                           0.63             0.18
# Wood Products                                     0.42             0.13
#
# Section                           Stone And Glass  Textiles  Transportation  \
# Section
# Animal Hides                                -0.43     -0.51            0.38
# Animal Products                              0.74      0.60           -0.35
# Animal and Vegetable Bi-Products             0.76      0.71           -0.59
# Arts and Antiques                            0.15      0.08           -0.00
# Chemical Products                            0.65      0.86           -0.72
# Foodstuffs                                   0.49      0.39           -0.57
# Footwear and Headwear                        0.61      0.48           -0.57
# Instruments                                  0.38      0.45           -0.26
# Machines                                    -0.14     -0.10            0.53
# Metals                                       0.82      0.69           -0.59
# Mineral Products                            -0.26      0.52           -0.44
# Miscellaneous                                0.39      0.69           -0.66
# Paper Goods                                  0.33      0.87           -0.75
# Plastics and Rubbers                         0.33     -0.11            0.01
# Precious Metals                              0.49     -0.06           -0.19
# Stone And Glass                              1.00      0.47           -0.43
# Textiles                                     0.47      1.00           -0.69
# Transportation                              -0.43     -0.69            1.00
# Vegetable Products                           0.43      0.81           -0.61
# Weapons                                      0.27     -0.56            0.43
# Wood Products                                0.38      0.10           -0.25
#
# Section                           Vegetable Products  Weapons  Wood Products
# Section
# Animal Hides                                   -0.59     0.19           0.32
# Animal Products                                 0.58    -0.16           0.22
# Animal and Vegetable Bi-Products                0.76    -0.12           0.06
# Arts and Antiques                               0.03     0.07           0.44
# Chemical Products                               0.67    -0.15           0.46
# Foodstuffs                                      0.41     0.12          -0.02
# Footwear and Headwear                           0.33     0.15           0.30
# Instruments                                     0.39     0.28           0.33
# Machines                                       -0.18     0.20          -0.03
# Metals                                          0.61     0.11           0.34
# Mineral Products                                0.16    -0.58           0.22
# Miscellaneous                                   0.54    -0.17           0.10
# Paper Goods                                     0.73    -0.49           0.16
# Plastics and Rubbers                           -0.29     0.63           0.42
# Precious Metals                                -0.00     0.18           0.13
# Stone And Glass                                 0.43     0.27           0.38
# Textiles                                        0.81    -0.56           0.10
# Transportation                                 -0.61     0.43          -0.25
# Vegetable Products                              1.00    -0.41          -0.20
# Weapons                                        -0.41     1.00           0.33
# Wood Products                                  -0.20     0.33           1.00
#
# [21 rows x 21 columns]

# %%
f = plt.figure(figsize=(10, 10)) # figure size 
plt.matshow(pivot_exports.corr(), fignum=f.number) # type of plot
plt.xticks(range(pivot_exports.shape[1]), pivot_exports.columns, fontsize=15, rotation=90) # x axis labels
plt.yticks(range(pivot_exports.shape[1]), pivot_exports.columns, fontsize=15) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
plt.show()

# %%
corr_matrix = pivot_exports.corr()
f, ax = plt.subplots(figsize=(16, 12))
# Create the heatmap without annotations
sns.heatmap(corr_matrix, annot=False, ax=ax, cmap='coolwarm', linewidths=0.5)

# Define a threshold to distinguish dark and light cells
threshold = corr_matrix.max().max() / 2  # This is an example threshold

# Manually annotate each cell with the correlation coefficient
for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        value = corr_matrix.iloc[i, j]
        text_color = "black" if value < threshold else "white"
        ax.text(j + 0.5, i + 0.5, f"{value:.2f}",
                horizontalalignment='center',
                verticalalignment='center',
                color=text_color)



# Now we set the title
plt.title('Correlation Matrix', fontsize=14)

# and finally show the plot
plt.show()

# %%
# Get the most and least exported sections
most_exported = pivot_exports.idxmax(axis=1)
least_exported = pivot_exports.idxmin(axis=1)

# Filter the unique labels for both graphs
most_exported_sections = most_exported.unique()
least_exported_sections = least_exported.unique()

# Get the sum of the trade values for each section
most_exported_data = pivot_exports[most_exported_sections].sum(axis=1)
least_exported_data = pivot_exports[least_exported_sections].sum(axis=1)

# Create the bar plot
fig, ax = plt.subplots(2, 1, figsize=(14, 12))

# Plot for most exported sections
sns.barplot(x=most_exported_data.index, y=most_exported_data.values, ax=ax[0])
ax[0].set_title('Most Exported Sections by Year')
ax[0].set_ylabel('Trade Value')
ax[0].set_xlabel('Year')
ax[0].tick_params(axis='both',direction='out', length=6, width=2, colors='r',
               grid_color='r', grid_alpha=0.5)
ax[0].legend(labels=most_exported_sections, title='Section')

# Custom color list for least exported sections
colors = ['blue'] * len(least_exported_data)
year_2013_index = least_exported_data.index.get_loc(2013)  # Find the index for the year 2013
if least_exported[2013] == 'Arts and Antiques':
    colors[year_2013_index] = 'orange'

# Plot for least exported sections with custom colors
sns.barplot(x=least_exported_data.index, y=least_exported_data.values, hue=least_exported_data.index, ax=ax[1], palette=colors)
ax[1].set_title('Least Exported Sections by Year')
ax[1].set_ylabel('Trade Value')
ax[1].set_xlabel('Year')
ax[1].tick_params(axis='both',direction='out', length=6, width=2, colors='r',
               grid_color='r', grid_alpha=0.5)


# Custom legend
legend_handles = [plt.Line2D([0], [0], color='blue', lw=6, label='Weapons'),
                  plt.Line2D([0], [0], color='orange', lw=6, label='Arts and Antiques in 2013')]
ax[1].legend(handles=legend_handles, title='Section')


plt.tight_layout()
plt.show()

# %%
least_exported, most_exported
#Checking to see the color for least_exported that has a breakpoint.
# Out:
# (Year
#  2012              Weapons
#  2013    Arts and Antiques
#  2014              Weapons
#  2015              Weapons
#  2016              Weapons
#  2017              Weapons
#  2018              Weapons
#  2019              Weapons
#  2020              Weapons
#  2021              Weapons
#  2022              Weapons
#  dtype: object,
#  Year
#  2012    Vegetable Products
#  2013    Vegetable Products
#  2014    Vegetable Products
#  2015    Vegetable Products
#  2016    Vegetable Products
#  2017    Vegetable Products
#  2018    Vegetable Products
#  2019    Vegetable Products
#  2020    Vegetable Products
#  2021    Vegetable Products
#  2022    Vegetable Products
#  dtype: object)

# %%
sns.lmplot(x='Vegetable Products', y='Animal Products', data= pivot_exports)
pd.options.display.float_format = '{:.2f}'.format  # Adjust as needed
